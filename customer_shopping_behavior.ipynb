# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\vedant\Downloads\customer_shopping_behavior.csv', encoding = 'unicode_escape')

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.describe( include = 'all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                   0
# age                           0
# gender                        0
# item_purchased                0
# category                      0
# purchase_amount               0
# location                      0
# size                          0
# color                         0
# season                        0
# review_rating                 0
# subscription_status           0
# shipping_type                 0
# discount_applied              0
# previous_purchases            0
# payment_method                0
# frequency_of_purchases        0
# agegroup                      0
# purchase_frequancy_days    1147
# dtype: int64

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x : x.fillna(x.median()))

# %%
df.columns = df.columns.str.lower()

# %%
df.columns = df.columns.str.replace(' ',"_")

# %%
 df = df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
#label for age group column
labels = ['young_adult','adult','middle_age','sinor']
df['agegroup'] = pd.qcut(df['age'], q = 4 , labels = labels)

# %%
df['frequency_of_purchases'].head(10)
# Out:
# 0    Fortnightly
# 1    Fortnightly
# 2         Weekly
# 3         Weekly
# 4       Annually
# 5         Weekly
# 6      Quarterly
# 7         Weekly
# 8       Annually
# 9      Quarterly
# Name: frequency_of_purchases, dtype: object

# %%
# CREATE COLUMN purchase frequancy dATE
frequency_mapping ={
    'Annually' : 365,
    'Quaterly' : 90 ,
    'Weekly' : 7,
    'Fortnightly' : 14,
    'Every 3 month' : 90,
    'Monthly' : 30,
    'Bi-Weekly' : 14 
}

df['purchase_frequancy_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequancy_days','frequency_of_purchases']].head(10)
# Out:
#    purchase_frequancy_days frequency_of_purchases
# 0                     14.0            Fortnightly
# 1                     14.0            Fortnightly
# 2                      7.0                 Weekly
# 3                      7.0                 Weekly
# 4                    365.0               Annually
# 5                      7.0                 Weekly
# 6                      NaN              Quarterly
# 7                      7.0                 Weekly
# 8                    365.0               Annually
# 9                      NaN              Quarterly

# %%
df[['discount_applied', 'promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
(df['discount_applied'] == df['promo_code_used']).all()
# Out:
# np.True_

# %%
df = df.drop('promo_code_used',axis= 1)

# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#    --- ------------------------------------ 1.6/17.7 MB 6.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.4/17.7 MB 6.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.6/17.7 MB 4.6 MB/s eta 0:00:04
#    ------ --------------------------------- 2.9/17.7 MB 3.6 MB/s eta 0:00:05
#    ------- -------------------------------- 3.1/17.7 MB 3.1 MB/s eta 0:00:05
#    ------- -------------------------------- 3.4/17.7 MB 2.7 MB/s eta 0:00:06
#    -------- ------------------------------- 3.7/17.7 MB 2.5 MB/s eta 0:00:06
#    -------- ------------------------------- 3.9/17.7 MB 2.3 MB/s eta 0:00:06
#    --------- ------------------------------ 4.2/17.7 MB 2.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 4.5/17.7 MB 2.1 MB/s eta 0:00:07
# ...

# %%
import mysql.connector

# Connect to the server
db = mysql.connector.connect(
  host='127.0.0.1',
  user="root",
  password="qwertynoob",
  database="customer_behavior"
)

print(db)

# %%
from sqlalchemy import create_engine

# !pip install pymysql

engine = create_engine('mysql+pymysql://root:qwertynoob@127.0.0.1:3306/customer_behavior')

df.to_sql(name='customer', con=engine, if_exists='append', index=False)

print("Data loaded successfully!")
# Out:
# ...
# Data loaded successfully!
